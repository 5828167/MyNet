# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math

from torch.optim import lr_scheduler
from torch.autograd import Variable

# %%
import argparse
import torch.optim as optim
from torchvision import datasets, transforms

# %%
import os
import sys
import numpy as np

# %%
test_model = torch.load('CapsNet.pt')

# %%
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
        transforms.ToTensor()
    ])),
    batch_size=1, shuffle=False)

# %%
dummy=1
s=0.
t=0.

for (x, y) in test_loader :
    x, y = Variable(x, requires_grad=True), Variable(y, requires_grad=False)
    _, probs = test_model(x, y)
    y_pred = np.argmax(probs.data.numpy())
    loss = nn.CrossEntropyLoss()(probs, y)
    loss.backward()
    epsilon = 0.1 
    x_grad   = torch.sign(x.grad.data)
    x_adversarial = torch.clamp(x.data + epsilon * x_grad, 0, 1)
    _, adversarial_probs = test_model(Variable(x_adversarial), y)
    y_pred_adversarial = np.argmax(adversarial_probs.data.numpy())
    
    print("{0} th example ".format(dummy))
    print ("True value: "+ str(y.data.numpy()[0])+"\nPredicted value : "+str(y_pred)+ "\nAdversarial :" + str(y_pred_adversarial)+"\n" )
    
    dummy+=1
    
    if y.data.numpy()[0]!=y_pred :
        t+=1
    
    if y_pred!=y_pred_adversarial :
        s+=1
    if dummy==100:
        break
        
print("Accuracy of test_model : {0:.3f} , Adversarials : {1:.3f}".format((t/dummy)*100, (s/dummy)*100))
# Out:
# PytorchCapsnet.py:28: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   c = F.softmax(self.b)
# PytorchCapsnet.py:38: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   c = F.softmax(b_batch.view(-1, output_caps)).view(-1, input_caps, output_caps, 1)
# 1 th example
# True value: 7
# Predicted value : 7
# Adversarial :7
#
# 2 th example
# True value: 2
# Predicted value : 2
# Adversarial :2
#
# 3 th example
# True value: 1
# Predicted value : 1
# Adversarial :4
#
# 4 th example
# True value: 0
# Predicted value : 0
# Adversarial :6
#
# 5 th example
# True value: 4
# Predicted value : 4
# Adversarial :4
#
# 6 th example
# True value: 1
# Predicted value : 1
# Adversarial :1
#
# 7 th example
# True value: 4
# Predicted value : 4
# Adversarial :9
#
# 8 th example
# True value: 9
# Predicted value : 9
# Adversarial :2
#
# 9 th example
# True value: 5
# Predicted value : 5
# Adversarial :8
#
# 10 th example
# True value: 9
# Predicted value : 9
# Adversarial :8
#
# 11 th example
# True value: 0
# Predicted value : 0
# Adversarial :0
#
# 12 th example
# True value: 6
# Predicted value : 6
# Adversarial :6
#
# 13 th example
# True value: 9
# Predicted value : 9
# Adversarial :9
#
# 14 th example
# True value: 0
# Predicted value : 0
# Adversarial :0
#
# 15 th example
# True value: 1
# Predicted value : 1
# Adversarial :1
#
# 16 th example
# True value: 5
# Predicted value : 5
# Adversarial :3
#
# 17 th example
# True value: 9
# Predicted value : 9
# Adversarial :9
#
# 18 th example
# True value: 7
# Predicted value : 7
# Adversarial :7
#
# 19 th example
# True value: 3
# Predicted value : 3
# Adversarial :5
#
# 20 th example
# True value: 4
# Predicted value : 4
# Adversarial :4
#
# 21 th example
# True value: 9
# Predicted value : 9
# Adversarial :9
#
# 22 th example
# True value: 6
# Predicted value : 6
# Adversarial :6
#
# 23 th example
# True value: 6
# Predicted value : 6
# Adversarial :8
#
# 24 th example
# True value: 5
# Predicted value : 5
# Adversarial :8
#
# 25 th example
# True value: 4
# Predicted value : 4
# Adversarial :4
#
# 26 th example
# True value: 0
# Predicted value : 0
# Adversarial :0
#
# 27 th example
# True value: 7
# Predicted value : 7
# Adversarial :9
#
# 28 th example
# True value: 4
# Predicted value : 4
# Adversarial :4
#
# 29 th example
# True value: 0
# Predicted value : 0
# Adversarial :0
#
# 30 th example
# True value: 1
# Predicted value : 1
# Adversarial :1
#
# 31 th example
# True value: 3
# Predicted value : 3
# Adversarial :3
#
# 32 th example
# True value: 1
# Predicted value : 1
# Adversarial :1
#
# 33 th example
# True value: 3
# Predicted value : 3
# Adversarial :3
#
# 34 th example
# True value: 4
# Predicted value : 4
# Adversarial :2
#
# 35 th example
# True value: 7
# Predicted value : 7
# Adversarial :7
#
# 36 th example
# True value: 2
# Predicted value : 2
# Adversarial :2
#
# 37 th example
# True value: 7
# Predicted value : 7
# Adversarial :2
#
# 38 th example
# True value: 1
# Predicted value : 1
# Adversarial :1
#
# 39 th example
# True value: 2
# Predicted value : 2
# Adversarial :2
#
# 40 th example
# True value: 1
# Predicted value : 1
# Adversarial :1
#
# 41 th example
# True value: 1
# Predicted value : 1
# Adversarial :8
#
# 42 th example
# True value: 7
# Predicted value : 7
# Adversarial :2
#
# 43 th example
# True value: 4
# Predicted value : 4
# Adversarial :4
#
# 44 th example
# True value: 2
# Predicted value : 2
# Adversarial :4
#
# 45 th example
# True value: 3
# Predicted value : 3
# Adversarial :0
#
# 46 th example
# True value: 5
# Predicted value : 5
# Adversarial :8
#
# 47 th example
# True value: 1
# Predicted value : 1
# Adversarial :1
#
# 48 th example
# True value: 2
# Predicted value : 2
# Adversarial :2
#
# 49 th example
# True value: 4
# Predicted value : 4
# Adversarial :4
#
# 50 th example
# True value: 4
# Predicted value : 4
# Adversarial :4
#
# 51 th example
# True value: 6
# Predicted value : 6
# Adversarial :6
#
# 52 th example
# True value: 3
# Predicted value : 3
# Adversarial :3
#
# 53 th example
# True value: 5
# Predicted value : 5
# Adversarial :3
#
# 54 th example
# True value: 5
# Predicted value : 5
# Adversarial :5
#
# 55 th example
# True value: 6
# Predicted value : 6
# Adversarial :6
#
# 56 th example
# True value: 0
# Predicted value : 0
# Adversarial :0
#
# 57 th example
# True value: 4
# Predicted value : 4
# Adversarial :4
#
# 58 th example
# True value: 1
# Predicted value : 1
# Adversarial :1
#
# 59 th example
# True value: 9
# Predicted value : 9
# Adversarial :9
#
# 60 th example
# True value: 5
# Predicted value : 5
# Adversarial :9
#
# 61 th example
# True value: 7
# Predicted value : 7
# Adversarial :7
#
# 62 th example
# True value: 8
# Predicted value : 8
# Adversarial :8
#
# 63 th example
# True value: 9
# Predicted value : 9
# Adversarial :8
#
# 64 th example
# True value: 3
# Predicted value : 3
# Adversarial :2
#
# 65 th example
# True value: 7
# Predicted value : 7
# Adversarial :7
#
# 66 th example
# True value: 4
# Predicted value : 4
# Adversarial :8
#
# 67 th example
# True value: 6
# Predicted value : 6
# Adversarial :6
#
# 68 th example
# True value: 4
# Predicted value : 4
# Adversarial :4
#
# 69 th example
# True value: 3
# Predicted value : 3
# Adversarial :3
#
# 70 th example
# True value: 0
# Predicted value : 0
# Adversarial :9
#
# 71 th example
# True value: 7
# Predicted value : 7
# Adversarial :7
#
# 72 th example
# True value: 0
# Predicted value : 0
# Adversarial :0
#
# 73 th example
# True value: 2
# Predicted value : 2
# Adversarial :2
#
# 74 th example
# True value: 9
# Predicted value : 8
# Adversarial :8
#
# 75 th example
# True value: 1
# Predicted value : 1
# Adversarial :1
#
# 76 th example
# True value: 7
# Predicted value : 7
# Adversarial :7
#
# 77 th example
# True value: 3
# Predicted value : 3
# Adversarial :3
#
# 78 th example
# True value: 2
# Predicted value : 2
# Adversarial :7
#
# 79 th example
# True value: 9
# Predicted value : 9
# Adversarial :8
#
# 80 th example
# True value: 7
# Predicted value : 7
# Adversarial :7
#
# 81 th example
# True value: 7
# Predicted value : 7
# Adversarial :9
#
# 82 th example
# True value: 6
# Predicted value : 6
# Adversarial :6
#
# 83 th example
# True value: 2
# Predicted value : 2
# Adversarial :2
#
# 84 th example
# True value: 7
# Predicted value : 7
# Adversarial :9
#
# 85 th example
# True value: 8
# Predicted value : 8
# Adversarial :8
#
# 86 th example
# True value: 4
# Predicted value : 4
# Adversarial :4
#
# 87 th example
# True value: 7
# Predicted value : 7
# Adversarial :7
#
# 88 th example
# True value: 3
# Predicted value : 3
# Adversarial :3
#
# 89 th example
# True value: 6
# Predicted value : 6
# Adversarial :6
#
# 90 th example
# True value: 1
# Predicted value : 1
# Adversarial :8
#
# 91 th example
# True value: 3
# Predicted value : 3
# Adversarial :3
#
# 92 th example
# True value: 6
# Predicted value : 6
# Adversarial :8
#
# 93 th example
# True value: 9
# Predicted value : 9
# Adversarial :8
#
# 94 th example
# True value: 3
# Predicted value : 3
# Adversarial :0
#
# 95 th example
# True value: 1
# Predicted value : 1
# Adversarial :0
#
# 96 th example
# True value: 4
# Predicted value : 4
# Adversarial :8
#
# 97 th example
# True value: 1
# Predicted value : 1
# Adversarial :1
#
# 98 th example
# True value: 7
# Predicted value : 7
# Adversarial :7
#
# 99 th example
# True value: 6
# Predicted value : 6
# Adversarial :6
#
# Accuracy of test_model : 1.000 , Adversarials : 34.000
